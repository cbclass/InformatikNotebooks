# %% [markdown]
# Notebook zu Python: Objektorientierte Programmierung: Klassen verwenden
#
# Version 1.3, 2. April. März 2024, Informatik, EAH Jena
#
# (c) Christina B. Class

# %% [markdown]
# ## Vorbereitung

# %% [markdown]
# Führen Sie die folgende Zeile aus, um das Modul mit den Klassen `Person` und `Telefonbuch` zu importieren.

# %%
from modules.TelefonBK import *

# %% [markdown]
# # Verwendung der Telefonbuch Anwendung

# %% [markdown]
# ## 1. Die Klassen

# %% [markdown]
# Die Telefonbuchanwendung besteht aus der Klasse `Person` und der Klasse `Telefonbuch`. Diese sind in der folgenden Abbildung dargestellt.
#
# Die Darstellung der Klassen ist in UML angegeben. Wir werden die einzelnen Elemente in den nächsten Veranstaltungen Schritt für Schritt kennenlernen.

# %% [markdown]
# ![Telefonbuch-2.png](attachment:Telefonbuch-2.png)

# %% [markdown]
# ## 2. Erzeugung von Objekten

# %% [markdown]
# Den Code der beiden Klassen haben wir oben durch die `import` Anweisung geladen. Wir können diese Klassen nun also verwenden.

# %% [markdown]
# Zuerst erzeugen wir ein Objekt für eine Person. Wir geben der Person den Namen "eine person" und die Telefonnummer "123".
#
# Führen Sie folgenden Code aus:

# %%
Person("eine person","123")

# %% [markdown]
# Sie werden als Out[] etwas in der Art wie
#
# <modules.TelefonBK.Person at 0x2cb59a6948>

# %% [markdown]
# sehen. Das Personenobjekt wurde zwar erzeugt, aber wir haben es "vergessen", können also nicht mehr darauf zugreifen, da wir es nicht in einer Variablen gespeichert haben. Ähnliches passiert auch hier:

# %%
list((1,2,3,4))

# %% [markdown]
# In obigem Code wird eine Liste erzeugt (Listen sind **auch** Objekte), die man allerdings nicht mehr weiter verwenden kann, da sie nicht gespeichert wurde.

# %% [markdown]
# Um das Personenobjekt nach der Erzeugung auch verwenden zu können, müssen wir es also in einer Variablen abspeichern:
#
# <a id='einePerson'></a>

# %%
einePerson=Person("eine person","123")

# %% [markdown]
# Wir können dieses Objekt nun mit `print()` ausgeben.

# %%
print(einePerson)

# %% [markdown]
# **Aufgabe:** Erzeugen Sie nun ein Personenobjekt `person2` mit einem von Ihnen gewählten Namen und einer Telefonnummer und geben Sie es aus.

# %%
# Ihre Loesung

# %% [markdown]
# ## 3. Aufruf von Methoden

# %% [markdown]
# Wir können dieses Objekt nun verwenden, indem wir seine Methoden aufrufen.

# %%
einePerson.getName()

# %%
einePerson.getTelefonNr()

# %%
print(einePerson)

# %%
einePerson.setTelefonNr('12121212')
print(einePerson)

# %% [markdown]
# **Aufgabe:** Verwenden Sie Ihr oben erzeugtes Personenobjekt `person2`.
# Geben Sie die Person aus. Ändern Sie die Telefonnummer und geben Sie die Person erneut aus.

# %%
# Ihre Loesung

# %% [markdown]
# ## 4. Verwendung des Telefonbuchs

# %% [markdown]
# Um ein Telefonbuch zu erzeugen, gehen wir ähnlich vor wie zur Erzeugung einer Person. Bei der Erzeugung müssen wir diesmal nur einen Parameter übergeben, den Namen des Telefonbuchs.
# Falls Sie noch einmal nachsehen wollen, finden Sie den Code zur Erzeugung einer Person [hier](#einePerson).

# %% [markdown]
# **Aufgabe:** Erzeugen Sie ein neues Telefonbuch und speichen Sie es in der Variable `dasTelefonbuch` ab. Sie können den Namen des Telefonbuchs frei wählen.
# <a id='telbook'></a>

# %%
# Ihre Loesung

# %% [markdown]
# Testen Sie, ob das Telefonbuch korrekt erzeugt wurde, indem Sie es ausgeben.

# %%
dasTelefonbuch.printTelBuch()

# %% [markdown]
# Sollten Sie hier einen Fehler haben, überprüfen Sie bitte [hier](#telbook), ob Ihr Telefonbuch in der Variable `dasTelefonbuch` abgespeichert ist.

# %% [markdown]
# Nun fügen wir die erzeugten Personen in das Telefonbuch ein.

# %%
dasTelefonbuch.insertPerson(einePerson)

# %% [markdown]
# **Aufgabe :** Fügen Sie nun auch das Objekt `person2`in das Telefonbuch ein und geben Sie das Telefonbuch anschließend aus.

# %%
# Ihre Loesung

# %% [markdown]
# Wir können Personen auch direkt in das Telefonbuch einfügen, ohne zuvor ein Objekt zu erzeugen. Das Objekt wird dann in der entsprechenden Methode des Telefonbuchs erzeugt.

# %%
dasTelefonbuch.insertInformation("andere Person",'11111')

# %% [markdown]
# In diesem Fall wurde die Information in das Telefonbuch eingefügt, aber wir haben uns das erzeugte Objekt nicht gemerkt, können also nicht direkt darauf zugreifen.
#
# **Aufgabe:** Die Information ist aber im Telefonbuch gespeichert. Überprüfen Sie das, indem Sie das Telefonbuch ausgeben.

# %%
# Ihre Loesung

# %% [markdown]
# **Aufgabe:** Tragen Sie die Information einer anderen Person mit `insertInformation()` in das Telefonbuch ein und merken Sie sich das zurückgegebene Objekt in der Variable `person3`. Geben Sie dann das Telefonbuch erneut aus, um zu kontrollieren, ob die Information richtig eingetragen ist.

# %%
# Ihre Loesung

# %% [markdown]
# Wenn Sie es richtig gemacht haben, funktioniert die folgende Zeile.

# %%
print(person3)

# %% [markdown]
# **Aufgabe:** Wir möchten nun die Telefonnummer von "andere Person" zu "123456" ändern.
# Gehen Sie wie folgt vor:
# 1. Rufen Sie die Methode `getPerson()` für das Telefonbuch auf und übergeben Sie als Parameterwert den Namen "andere Person". Speichern Sie das zurückgegebene Objekt in der Variablen `andereP`.
# 2. Verändern Sie die Telefonnummer von `andereP`mit der Methode `setTelefonNr()`.
# 3. Rufen Sie die Methode `getTelefonNr()` von `andereP` auf, um zu überprüfen, ob die Veränderung erfolgt ist.
# 4. Geben Sie das Telefonbuch aus und überprüfen Sie die Einträge.

# %%
# Ihre Loesung

# %% [markdown]
# --Ende des Notebooks--

# %% [markdown]
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-nd/4.0/"><img alt="Creative Commons Lizenzvertrag" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-nd/4.0/88x31.png" /></a><br /><span xmlns:dct="http://purl.org/dc/terms/" property="dct:title">Dieses Notebook wurde von Christina B. Class für die Lehre an der EAH Jena erstellt. Es ist lizenziert unter einer <a rel="license" href="http://creativecommons.org/licenses/by-nc-nd/4.0/">Creative Commons Namensnennung - Nicht kommerziell - Keine Bearbeitungen 4.0 International Lizenz</a>.
